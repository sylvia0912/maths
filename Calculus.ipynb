# %% [markdown]
# ## Calculus - it is study of change

# %% [markdown]
# - Calculus, originally called infinitesimal calculus or "the calculus of infinitesimals", is the mathematical study of continuous change, in the same way that geometry is the study of shape, and algebra is the study of generalizations of arithmetic operations.
# - The two main types are **'Differential calculus'** and **'Integral calculus'**

# %% [markdown]
# Optimization technique called gradient descent based on differential calculus. It will help us discover the minimum value iteratively.

# %% [markdown]
# ### First Derivative / Slope / Rate of change

# %% [markdown]
# 1. In a smoothly changing function a maximum or minimum is always where the function flattens out.
# 2. Where does it flatten out?  Where the slope is zero.
# 3. Where is the slope zero?  The Derivative tells us! Foundational result that the minimum of a function is reliably located at the point where the derivative of the function takes on a zero value.

# %% [markdown]
# ### Second Derivative Test - to detect whether maxima or minima

# %% [markdown]
# When a function's slope is zero at x, and the second derivative at x is:
# - less than 0, it is a local maximum
# - greater than 0, it is a local minimum
# - equal to 0, then the test fails (there may be other ways of finding out though)

# %% [markdown]
# ### Example

# %% [markdown]
# ![Xnip2022-07-21_13-58-35.jpg](attachment:Xnip2022-07-21_13-58-35.jpg)
